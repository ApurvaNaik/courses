# %% [markdown]
# <a href="https://colab.research.google.com/github/ApurvaNaik/courses/blob/master/TF_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflo as tf
import numpy as np

# %%
# generate normal data in tf
a = 5
b = 0
c = 1
x = 10

# gaussian distribution can be generated by:

l = tf.exp(tf.negative(tf.square(x-b)/tf.multiply(2, tf.square(c))))
l
# Out:
# <tf.Tensor 'Exp:0' shape=() dtype=float64>
